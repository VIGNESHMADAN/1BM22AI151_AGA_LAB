# %% [markdown]
# $LAB_1-13-03-2025$

# %%
#SIMPLE AUTOENCODER
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


def create_autoencoder(input_dim, encoding_dim):
  input_layer = keras.Input(shape=(input_dim,))
  encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
  decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)
  autoencoder = keras.Model(input_layer, decoded)


  encoder = keras.Model(input_layer, encoded)

  encoded_input = keras.Input(shape=(encoding_dim,))
  decoder_layer = autoencoder.layers[-1]
  decoder = keras.Model(encoded_input, decoder_layer(encoded_input))
  return autoencoder, encoder, decoder

input_dim = 10
encoding_dim = 10

autoencoder, encoder, decoder = create_autoencoder(input_dim, encoding_dim)
autoencoder.compile(optimizer='adam', loss='mse')


import numpy as np
data = np.random.rand(100, input_dim)

autoencoder.fit(data, data, epochs=10, batch_size=32, shuffle=True)



encoded_data = encoder.predict(data[:3])
decoded_data = decoder.predict(encoded_data)
print("Encoded Data shape:",encoded_data.shape)
print("Decoded Data shape:",decoded_data.shape)
print("first 3 encoded samples:\n",encoded_data)
print("first 3 decoded samples:\n",decoded_data)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0937
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0905
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0910
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0901
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0917
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0890
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0889
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0895
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0862
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0871
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Encoded Data shape: (3, 10)
# Decoded Data shape: (3, 10)
# first 3 encoded samples:
#  [[0.         0.         0.73510784 0.09341715 0.         0.73506343
#   0.         0.         0.17668428 0.11326545]
#  [0.         0.         0.05361171 0.         0.         1.038367
#   0.12690319 0.         0.         0.14661486]
#  [0.         0.         0.         0.2698278  0.         0.74990344
#   0.27422026 0.         0.21135773 0.20116636]]
# first 3 decoded samples:
#  [[0.54820716 0.6248387  0.64934015 0.62035793 0.4250449  0.51153535
#   0.4980868  0.4126668  0.4022761  0.5284381 ]
#  [0.47115785 0.6097448  0.577657   0.5830547  0.5097648  0.51667863
#   0.56785446 0.43494213 0.3651175  0.48227796]
#  [0.45842457 0.51318747 0.57752967 0.5947383  0.46709028 0.4924033
#   0.56794196 0.46776828 0.3813518  0.5120202 ]]

# %%
#SIMPLE AUTOENCODER(UNDERCOMPLETE)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# autoencoder model
def create_autoencoder(input_dim, encoding_dim):
  input_layer = keras.Input(shape=(input_dim,))
  encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
  decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)
  autoencoder = keras.Model(input_layer, decoded)

  # Encoder
  encoder = keras.Model(input_layer, encoded)

  # Decoder
  encoded_input = keras.Input(shape=(encoding_dim,))
  decoder_layer = autoencoder.layers[-1]
  decoder = keras.Model(encoded_input, decoder_layer(encoded_input))
  return autoencoder, encoder, decoder

input_dim = 10
encoding_dim = 5

autoencoder, encoder, decoder = create_autoencoder(input_dim, encoding_dim)
autoencoder.compile(optimizer='adam', loss='mse')


import numpy as np
data = np.random.rand(100, input_dim)#generating data

# Training
autoencoder.fit(data, data, epochs=10, batch_size=32, shuffle=True)



encoded_data = encoder.predict(data[:3])
decoded_data = decoder.predict(encoded_data)
print("Encoded Data shape:",encoded_data.shape)
print("Decoded Data shape:",decoded_data.shape)
print("first 3 encoded samples:\n",encoded_data)
print("first 3 decoded samples:\n",decoded_data)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0848
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0842
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0839
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0842
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0838
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0828
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0815
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0833
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0819
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Encoded Data shape: (3, 5)
# Decoded Data shape: (3, 10)
# first 3 encoded samples:
#  [[0.         0.         0.3700875  0.         0.        ]
#  [0.05346032 0.23747027 0.         0.         0.        ]
#  [0.         0.43466884 0.         0.         0.        ]]
# first 3 decoded samples:
#  [[0.45586264 0.5165726  0.47758353 0.48420587 0.482719   0.48371103
#   0.49750215 0.5421555  0.53613937 0.4765338 ]
#  [0.51522756 0.47723082 0.5163043  0.5242867  0.49973816 0.52704126
#   0.5282043  0.48809952 0.52048606 0.475292  ]
#  [0.5142479  0.45369163 0.5404352  0.53538984 0.48457503 0.5547521
#   0.54859394 0.49718422 0.52730376 0.47109503]]

# %%
#SIMPLE AUTOENCODER(OVERCOMPLETE)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# autoencoder model
def create_autoencoder(input_dim, encoding_dim):
  input_layer = keras.Input(shape=(input_dim,))
  encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
  decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)
  autoencoder = keras.Model(input_layer, decoded)

  # Encoder
  encoder = keras.Model(input_layer, encoded)

  # Decoder
  encoded_input = keras.Input(shape=(encoding_dim,))
  decoder_layer = autoencoder.layers[-1]
  decoder = keras.Model(encoded_input, decoder_layer(encoded_input))
  return autoencoder, encoder, decoder

input_dim = 10
encoding_dim = 15

autoencoder, encoder, decoder = create_autoencoder(input_dim, encoding_dim)
autoencoder.compile(optimizer='adam', loss='mse')


import numpy as np
data = np.random.rand(100, input_dim)#generating data

# Training
autoencoder.fit(data, data, epochs=10, batch_size=32, shuffle=True)


encoded_data = encoder.predict(data[:3])
decoded_data = decoder.predict(encoded_data)
print("Encoded Data shape:",encoded_data.shape)
print("Decoded Data shape:",decoded_data.shape)
print("first 3 encoded samples:\n",encoded_data)
print("first 3 decoded samples:\n",decoded_data)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0947
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0938
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0927
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0923
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0918
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0902
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0899
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0899
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0891
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Encoded Data shape: (3, 15)
# Decoded Data shape: (3, 10)
# first 3 encoded samples:
#  [[0.0191622  0.         0.         0.04741561 0.23830175 0.
#   0.5366467  0.         0.         0.23846057 0.         0.
#   0.         0.32733074 0.3517311 ]
#  [0.         0.         0.03120183 0.3672876  0.06221185 0.
#   0.27200568 0.28625572 0.00662773 0.         0.         0.20734307
#   0.         0.32505205 0.        ]
#  [0.         0.         0.         0.19564697 0.0700065  0.
#   0.3201272  0.         0.         0.44451052 0.         0.
#   0.         0.01786593 0.84080213]]
# first 3 decoded samples:
#  [[0.48864278 0.40795726 0.513169   0.46944377 0.49252623 0.5596356
#   0.598868   0.58176976 0.46697196 0.458712  ]
#  [0.47307217 0.44146585 0.5752261  0.4722512  0.47304928 0.55541754
#   0.5033568  0.5260812  0.54422677 0.47342813]
#  [0.52146786 0.39893314 0.42910826 0.4655714  0.44519997 0.57991517
#   0.6069258  0.51577324 0.42098227 0.43715557]]
